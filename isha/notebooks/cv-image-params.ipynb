# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1aff284-c1b9-4bbd-abcf-728f406a52ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1aff284-c1b9-4bbd-abcf-728f406a52ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

img1 = cv2.imread("diamond.jpg")

if img1 is not None:
    # Convert to grayscale
    gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Edge detection
    edges = cv2.Canny(blurred, 50, 100)

    # Find contours
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Assuming the largest contour is the diamond
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)

        # Get the bounding rectangle
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Draw the bounding rectangle on the image
        cv2.rectangle(img1, (x, y), (x + w, y + h), (0, 220, 0), 2)

        # Display the image with the bounding box
        cv2_imshow(img1)

        # Output the dimensions
        print(f"Length: {w} ")
        print(f"Width: {h} ")
    else:
        print("No contours found.")
else:
    print("Error: Image not found or cannot be read.")
# Out:
# <PIL.Image.Image image mode=RGB size=180x180>
# Length: 59
# Width: 125

# %%
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Assuming the largest contour is the diamond
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)

        # Get the bounding rectangle
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Draw the bounding rectangle on the image
        cv2.rectangle(img1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display the image with the bounding box
        cv2_imshow(img1)

        # Output the dimensions
        print(f"Length: {w} pixels")
        print(f"Width: {h} pixels")
    else:
        print("No contours found.")
else:
    print("Error: Image not found or cannot be read.")
# Out:
#   File "<ipython-input-21-637d7829bc09>", line 4
#     blurred = cv2.GaussianBlur(gray, (5, 5), 0)
#     ^
# IndentationError: unexpected indent
